# %%
import alpaca_trade_api as tradeapi

api = tradeapi.REST('PKVBXZRT0VWL3U5RQG3Y', 'Mnm9xzhzrFh2K7b3FoD2z6gIxLtth0u64XlPrNl9', base_url='https://paper-api.alpaca.markets')

# %%
portfolio=api.list_positions()
for asset in portfolio:
    print(asset)
# Out:
# Position({   'asset_class': 'us_equity',
#     'asset_id': 'b0b6dd9d-8b9b-48a9-ba46-b9d54906e415',
#     'avg_entry_price': '114.4622222222222222',
#     'change_today': '0.0111333391319475',
#     'cost_basis': '1030.16',
#     'current_price': '116.25',
#     'exchange': 'NASDAQ',
#     'lastday_price': '114.97',
#     'market_value': '1046.25',
#     'qty': '9',
#     'side': 'long',
#     'symbol': 'AAPL',
#     'unrealized_intraday_pl': '10.13',
#     'unrealized_intraday_plpc': '0.0097768598231865',
#     'unrealized_pl': '16.09',
#     'unrealized_plpc': '0.0156189329812845'})

# %%
def sell():
    #Liquidates position
    portfolio=api.list_positions()
    for asset in portfolio:
        api.submit_order(
        symbol=asset.symbol,
        qty=asset.qty,
        side='sell',
        type='market',
        time_in_force='gtc'
        )

# %%
sell()
api.list_positions()
# Out:
# []

# %%
for asset in api.list_assets():
    if asset.tradable:
        print("We can trade "+str(asset.symbol))
# Out:
# We can trade MTZ
# We can trade SPGI
# We can trade AN
# We can trade ANF
# We can trade AGFS
# We can trade AIR
# We can trade ALLY
# We can trade BDN
# We can trade BIDU
# We can trade BSX
# We can trade BWXT
# We can trade COTY
# We can trade CVE
# We can trade DNN
# We can trade DWLD
# We can trade EMN
# We can trade FMC
# We can trade FSTR
# We can trade FUD
# We can trade FXI
# We can trade GEF
# We can trade GHC
# We can trade GRC
# We can trade HAS
# We can trade HPP
# We can trade IT
# We can trade LARK
# We can trade LII
# We can trade LUB
# We can trade LUMO
# We can trade MCO
# We can trade MET
# We can trade MGM
# We can trade MIN
# We can trade MOG.A
# We can trade MTC
# We can trade ORSNU
# We can trade PHG
# We can trade QNST
# We can trade RACE
# We can trade SCL
# We can trade STRS
# We can trade TCO
# We can trade TDSB
# We can trade VOYA
# We can trade VTR
# We can trade WEX
# We can trade AACG
# We can trade AACQ
# We can trade AADR
# We can trade AAME
# We can trade AAOI
# We can trade AAP
# We can trade AACQU
# We can trade AAMC
# We can trade AAN
# We can trade AAON
# We can trade AAT
# We can trade AAXJ
# We can trade AB
# We can trade ABC
# We can trade ABEO
# We can trade ABEV
# We can trade ABM
# We can trade ABR
# We can trade ABR-B
# We can trade ABT
# We can trade ABUS
# We can trade ACA
# We can trade ACAM
# We can trade ACB
# We can trade ACC
# We can trade ACCO
# We can trade ACER
# We can trade ACET
# We can trade ACEVU
# We can trade ACGLO
# We can trade ACH
# We can trade ACHV
# We can trade ACIA
# We can trade ACIU
# We can trade ACLS
# We can trade ACMR
# We can trade ACNB
# We can trade ACND.U
# We can trade ACP
# We can trade ACRS
# We can trade ACSG
# We can trade ACST
# We can trade ACTCU
# We can trade ACU
# We can trade ACWF
# We can trade ACWV
# We can trade ACY
# We can trade ADBE
# We can trade AAU
# We can trade AAWW
# We can trade AAXN
# We can trade ABBV
# We can trade ABCB
# We can trade ABEQ
# We can trade ABIO
# We can trade ABMD
# We can trade ABR-A
# We can trade ABR-C
# We can trade ABTX
# We can trade AC
# We can trade ACAD
# We can trade ACAMU
# We can trade ACBI
# We can trade ACCD
# We can trade ACEL
# We can trade ACES
# We can trade ACEV
# We can trade ACGL
# We can trade ACGLP
# We can trade ACHC
# We can trade ACI
# We can trade ACIO
# We can trade ACIW
# We can trade ACM
# We can trade ACN
# We can trade ACND
# We can trade ACOR
# We can trade ACRE
# We can trade ACRX
# We can trade ACSI
# We can trade ACT
# We can trade ACTG
# We can trade ACV
# We can trade ACWI
# We can trade ACWX
# We can trade ADAP
# We can trade ADC
# We can trade ADES
# We can trade ADI
# We can trade ADM
# We can trade ADME
# We can trade ADMS
# We can trade ADCT
# We can trade ADFI
# We can trade ADIL
# We can trade ADMA
# We can trade ADMP
# We can trade ADNT
# We can trade ADP
# We can trade ADRE
# We can trade ADSK
# We can trade ADTN
# We can trade ADUS
# We can trade ADX
# We can trade ADXS
# We can trade AEB
# We can trade AEF
# We can trade AEG
# We can trade AEHR
# We can trade AEL
# We can trade AEL-B
# We can trade AEMD
# We can trade AEP
# We can trade AEPPZ
# We can trade AERI
# We can trade AESE
# We can trade AEY
# We can trade AEZS
# We can trade AFC
# We can trade AFGB
# We can trade AFGD
# We can trade AFGH
# We can trade AFI
# We can trade AFIF
# We can trade AFINP
# We can trade AFL
# We can trade AFMC
# We can trade AFSM
# We can trade AFTY
# We can trade AG
# We can trade AGBAR
# We can trade AGCO
# We can trade AGD
# We can trade ADPT
# We can trade ADS
# We can trade ADSW
# We can trade ADTX
# We can trade ADVM
# We can trade ADXN
# We can trade AE
# We can trade AEE
# We can trade AEFC
# We can trade AEGN
# We can trade AEIS
# We can trade AEL-A
# We can trade AEM
# We can trade AEO
# We can trade AEPPL
# We can trade AER
# We can trade AES
# We can trade AESR
# We can trade AEYE
# We can trade AFB
# We can trade AFG
# We can trade AFGC
# We can trade AFGE
# We can trade AFIB
# We can trade AFIN
# We can trade AFK
# We can trade AFLG
# We can trade AFMD
# We can trade AFT
# We can trade AFYA
# We can trade AGBA
# We can trade AGBAU
# We can trade AGCUU
# We can trade AGE
# We can trade AGG
# We can trade AGGY
# We can trade AGIO
# We can trade AGM
# We can trade AGM-D
# We can trade AGM-F
# We can trade AGEN
# We can trade AGGP
# We can trade AGI
# We can trade AGLE
# We can trade AGM-C
# We can trade AGM-E
# We can trade AGM.A
# We can trade AGNC
# We can trade AGNCN
# We can trade AGNCP
# We can trade AGO-B
# We can trade AGO-F
# We can trade AGRO
# We can trade AGS
# We can trade AGTC
# We can trade AGYS
# We can trade AGZD
# We can trade AHC
# We can trade AHH
# We can trade AHL-C
# We can trade AHL-E
# We can trade AHT
# We can trade AHT-F
# We can trade AHT-H
# We can trade AI
# We can trade AI-C
# We can trade AIEQ
# We can trade AIG
# We can trade AIH
# We can trade AIIQ
# We can trade AIMC
# We can trade AIN
# We can trade AINV
# We can trade AIQ
# We can trade AIRG
# We can trade AIRR
# We can trade AIRTP
# We can trade AIV
# We can trade AIZ
# We can trade AGMH
# We can trade AGNCM
# We can trade AGNCO
# We can trade AGO
# We can trade AGO-E
# We can trade AGQ
# We can trade AGRX
# We can trade AGT
# We can trade AGX
# We can trade AGZ
# We can trade AHACU
# We can trade AHCO
# We can trade AHH-A
# We can trade AHL-D
# We can trade AHPI
# We can trade AHT-D
# We can trade AHT-G
# We can trade AHT-I
# We can trade AI-B
# We can trade AIA
# We can trade AIF
# We can trade AIG-A
# We can trade AIHS
# We can trade AIM
# We can trade AIMT
# We can trade AINC
# We can trade AIO
# We can trade AIRI
# We can trade AIRT
# We can trade AIT
# We can trade AIW
# We can trade AIZP
# We can trade AJRD
# We can trade AJXA
# We can trade AKCA
# We can trade AKO.A
# We can trade AKR
# We can trade AKTS
# We can trade AKU
# We can trade AL
# We can trade ALAC
# We can trade AJG
# We can trade AJX
# We can trade AKAM
# We can trade AKBA
# We can trade AKER
# We can trade AKO.B
# We can trade AKRO
# We can trade AKTX
# We can trade AKUS
# We can trade AL-A
# We can trade ALACR
# We can trade ALB
# We can trade ALC
# We can trade ALDX
# We can trade ALEC
# We can trade ALFA
# We can trade ALGN
# We can trade ALIM
# We can trade ALIN-B
# We can trade ALJJ
# We can trade ALKS
# We can trade ALL-B
# We can trade ALL-H
# We can trade ALLE
# We can trade ALLO
# We can trade ALNA
# We can trade ALOT
# We can trade ALPN
# We can trade ALRS
# We can trade ALSN
# We can trade ALTA
# We can trade ALTL
# We can trade ALTR
# We can trade ALTY
# We can trade ALUS.U
# We can trade ALVR
# We can trade ALXN
# We can trade ALYA
# We can trade AMAG
# We can trade AMAT
# We can trade AMBC
# We can trade AMC
# We can trade AMCI
# We can trade AMCR
# We can trade ALACU
# We can trade ALBO
# We can trade ALCO
# We can trade ALE
# We can trade ALEX
# We can trade ALG
# We can trade ALGT
# We can trade ALIN-A
# We can trade ALIN-E
# We can trade ALK
# We can trade ALL
# We can trade ALL-G
# We can trade ALL-I
# We can trade ALLK
# We can trade ALLT
# We can trade ALLY-A
# We can trade ALNY
# We can trade ALP-Q
# We can trade ALRM
# We can trade ALSK
# We can trade ALT
# We can trade ALTG
# We can trade ALTM
# We can trade ALTS
# We can trade ALUS
# We can trade ALV
# We can trade ALX
# We can trade ALXO
# We can trade AM
# We can trade AMAL
# We can trade AMBA
# We can trade AMBO
# We can trade AMCA
# We can trade AMCIU
# We can trade AMCX
# We can trade AMED
# We can trade AMG
# We can trade AMH
# We can trade AMH-E
# We can trade AMH-G
# We can trade AMHC
# We can trade AMJ
# We can trade AME
# We can trade AMEH
# We can trade AMGN
# We can trade AMH-D
# We can trade AMH-F
# We can trade AMH-H
# We can trade AMHCU
# We can trade AMK
# We can trade AMLP
# We can trade AMNA
# We can trade AMND
# We can trade AMOT
# We can trade AMP
# We can trade AMPH
# We can trade AMRB
# We can trade AMRH
# We can trade AMRN
# We can trade AMRX
# We can trade AMSC
# We can trade AMST
# We can trade AMT
# We can trade AMTBB
# We can trade AMTX
# We can trade AMUB
# We can trade AMWL
# We can trade AMYT
# We can trade AMZN
# We can trade ANAT
# We can trade ANDA
# We can trade ANDAU
# We can trade ANET
# We can trade ANGI
# We can trade ANGO
# We can trade ANH-A
# We can trade ANH-C
# We can trade ANIP
# We can trade ANNX
# We can trade ANSS
# We can trade ANVS
# We can trade AOA
# We can trade AOK
# We can trade AON
# We can trade AOR
# We can trade AMKR
# We can trade AMN
# We can trade AMNB
# We can trade AMOM
# We can trade AMOV
# We can trade AMPE
# We can trade AMPY
# We can trade AMRC
# We can trade AMRK
# We can trade AMRS
# We can trade AMS
# We can trade AMSF
# We can trade AMSWA
# We can trade AMTB
# We can trade AMTI
# We can trade AMU
# We can trade AMWD
# We can trade AMX
# We can trade AMZA
# We can trade ANAB
# We can trade ANCN
# We can trade ANDAR
# We can trade ANDE
# We can trade ANGL
# We can trade ANH
# We can trade ANH-B
# We can trade ANIK
# We can trade ANIX
# We can trade ANPC
# We can trade ANTE
# We can trade ANTM
# We can trade ANY
# We can trade AOD
# We can trade AOM
# We can trade AONE.U
# We can trade AOS
# We can trade AOUT
# We can trade APA
# We can trade APD
# We can trade APEI
# We can trade APEX
# We can trade APH
# We can trade API
# We can trade AOSL
# We can trade AP
# We can trade APAM
# We can trade APDN
# We can trade APEN
# We can trade APG
# We can trade APHA
# We can trade APLE
# We can trade APLT
# We can trade APO
# We can trade APO-B
# We can trade APOP
# We can trade APPN
# We can trade APRE
# We can trade APSG.U
# We can trade APTO
# We can trade APTV
# We can trade APTX
# We can trade APWC
# We can trade APXTU
# We can trade AQB
# We can trade AQN
# We can trade AQNB
# We can trade AQUA
# We can trade ARA
# We can trade ARAY
# We can trade ARC
# We can trade ARCC
# We can trade ARCH
# We can trade ARCO
# We can trade ARDC
# We can trade ARDX
# We can trade AREC
# We can trade ARES-A
# We can trade ARGD
# We can trade ARGO-A
# We can trade ARGX
# We can trade ARKF
# We can trade ARKK
# We can trade ARKR
# We can trade ARL
# We can trade ARLP
# We can trade APLS
# We can trade APM
# We can trade APO-A
# We can trade APOG
# We can trade APPF
# We can trade APPS
# We can trade APRN
# We can trade APT
# We can trade APTS
# We can trade APTV-A
# We can trade APVO
# We can trade APXT
# We can trade APYX
# We can trade AQMS
# We can trade AQNA
# We can trade AQST
# We can trade AR
# We can trade ARAV
# We can trade ARB
# We can trade ARCB
# We can trade ARCE
# We can trade ARCM
# We can trade ARCT
# We can trade ARD
# We can trade ARDS
# We can trade ARE
# We can trade ARES
# We can trade ARGO
# We can trade ARGT
# We can trade ARI
# We can trade ARKG
# We can trade ARKQ
# We can trade ARKW
# We can trade ARLO
# We can trade ARMK
# We can trade ARMR
# We can trade ARNC
# We can trade ARPO
# We can trade ARR
# We can trade ARTL
# We can trade ARTW
# We can trade ARW
# We can trade ARYA
# We can trade ARMP
# We can trade ARNA
# We can trade AROW
# We can trade ARQT
# We can trade ARR-C
# We can trade ARTNA
# We can trade ARVN
# We can trade ARWR
# We can trade ARYB
# We can trade ASA
# We can trade ASAQ.U
# We can trade ASB-C
# We can trade ASB-E
# We can trade ASC
# We can trade ASET
# We can trade ASGI
# We can trade ASH
# We can trade ASHS
# We can trade ASIX
# We can trade ASM
# We can trade ASML
# We can trade ASND
# We can trade ASPL.U
# We can trade ASPS
# We can trade ASR
# We can trade ASRV
# We can trade ASTC
# We can trade ASUR
# We can trade ASYS
# We can trade ATAX
# We can trade ATCO-D
# We can trade ATCO-G
# We can trade ATCO-I
# We can trade ATEC
# We can trade ATEX
# We can trade ATH
# We can trade ATH-B
# We can trade ATHA
# We can trade ATHX
# We can trade ATIF
# We can trade ATLC
# We can trade ARYBU
# We can trade ASAN
# We can trade ASB
# We can trade ASB-D
# We can trade ASB-F
# We can trade ASEA
# We can trade ASG
# We can trade ASGN
# We can trade ASHR
# We can trade ASHX
# We can trade ASLN
# We can trade ASMB
# We can trade ASO
# We can trade ASPN
# We can trade ASPU
# We can trade ASRT
# We can trade ASRVP
# We can trade ASTE
# We can trade ASX
# We can trade AT
# We can trade ATCO
# We can trade ATCO-E
# We can trade ATCO-H
# We can trade ATCX
# We can trade ATEN
# We can trade ATGE
# We can trade ATH-A
# We can trade ATH-C
# We can trade ATHE
# We can trade ATI
# We can trade ATKR
# We can trade ATLO
# We can trade ATNI
# We can trade ATNX
# We can trade ATOM
# We can trade ATR
# We can trade ATRC
# We can trade ATRO
# We can trade ATSG
# We can trade ATUS
# We can trade ATVI
# We can trade AU
# We can trade ATMP
# We can trade ATNM
# We can trade ATO
# We can trade ATOS
# We can trade ATRA
# We can trade ATRI
# We can trade ATRS
# We can trade ATTO
# We can trade ATV
# We can trade ATXI
# We can trade AUB
# We can trade AUBN
# We can trade AUG
# We can trade AUMN
# We can trade AUPH
# We can trade AUTL
# We can trade AUVI
# We can trade AVA
# We can trade AVAN.U
# We can trade AVB
# We can trade AVCT
# We can trade AVDE
# We can trade AVDV
# We can trade AVEO
# We can trade AVGOP
# We can trade AVK
# We can trade AVNS
# We can trade AVO
# We can trade AVT
# We can trade AVTR-A
# We can trade AVUV
# We can trade AVY
# We can trade AWAY
# We can trade AWH
# We can trade AWK
# We can trade AWR
# We can trade AWX
# We can trade AXAS
# We can trade AXGN
# We can trade AXL
# We can trade AXNX
# We can trade AXP
# We can trade AUBAP
# We can trade AUDC
# We can trade AUGZ
# We can trade AUSF
# We can trade AUTO
# We can trade AUY
# We can trade AVAL
# We can trade AVAV
# We can trade AVCO
# We can trade AVD
# We can trade AVDL
# We can trade AVEM
# We can trade AVGO
# We can trade AVGR
# We can trade AVID
# We can trade AVLR
# We can trade AVNW
# We can trade AVRO
# We can trade AVTR
# We can trade AVUS
# We can trade AVXL
# We can trade AVYA
# We can trade AWF
# We can trade AWI
# We can trade AWP
# We can trade AWRE
# We can trade AWTM
# We can trade AX
# We can trade AXDX
# We can trade AXGT
# We can trade AXLA
# We can trade AXO
# We can trade AXR
# We can trade AXS-E
# We can trade AXTA
# We can trade AXU
# We can trade AYI
# We can trade AYRO
# We can trade AZAA
# We can trade AZAO
# We can trade AZBL
# We can trade AZEK
# We can trade AZO
# We can trade AXS
# We can trade AXSM
# We can trade AXTI
# We can trade AY
# We can trade AYLA
# We can trade AYX
# We can trade AZAL
# We can trade AZBA
# We can trade AZBO
# We can trade AZN
# We can trade AZPN
# We can trade AZRX
# We can trade AZZ
# We can trade BA
# We can trade BABA
# We can trade BAC-A
# We can trade BAC-C
# We can trade BAC-K
# We can trade BAC-M
# We can trade BAF
# We can trade BAK
# We can trade BAM
# We can trade BANC-D
# We can trade BAND
# We can trade BANFP
# We can trade BANX
# We can trade BAPR
# We can trade BASI
# We can trade BATL
# We can trade BATRK
# We can trade BAUG
# We can trade BB
# We can trade BBAX
# We can trade BBC
# We can trade BBCP
# We can trade BBDC
# We can trade BBEU
# We can trade BBGI
# We can trade BBI
# We can trade BBIO
# We can trade BBK
# We can trade BBMC
# We can trade AZRE
# We can trade AZUL
# We can trade B
# We can trade BAB
# We can trade BAC
# We can trade BAC-B
# We can trade BAC-E
# We can trade BAC-L
# We can trade BAC-N
# We can trade BAH
# We can trade BAL
# We can trade BANC
# We can trade BANC-E
# We can trade BANF
# We can trade BANR
# We can trade BAP
# We can trade BAR
# We can trade BATRA
# We can trade BATT
# We can trade BAX
# We can trade BBAR
# We can trade BBBY
# We can trade BBCA
# We can trade BBD
# We can trade BBDO
# We can trade BBF
# We can trade BBH
# We can trade BBIN
# We can trade BBJP
# We can trade BBL
# We can trade BBN
# We can trade BBQ
# We can trade BBSA
# We can trade BBU
# We can trade BBVA
# We can trade BBY
# We can trade BC-A
# We can trade BC-C
# We can trade BCBP
# We can trade BCD
# We can trade BCE
# We can trade BBP
# We can trade BBRE
# We can trade BBSI
# We can trade BBUS
# We can trade BBW
# We can trade BC
# We can trade BC-B
# We can trade BCAT
# We can trade BCC
# We can trade BCDA
# We can trade BCEI
# We can trade BCH
# We can trade BCLI
# We can trade BCML
# We can trade BCOV
# We can trade BCPC
# We can trade BCRX
# We can trade BCSF
# We can trade BCTG
# We can trade BCV-A
# We can trade BCYC
# We can trade BDCS
# We can trade BDCY
# We can trade BDGE
# We can trade BDL
# We can trade BDR
# We can trade BDSI
# We can trade BE
# We can trade BEAT
# We can trade BEDU
# We can trade BEKE
# We can trade BELFB
# We can trade BEP
# We can trade BEPC
# We can trade BEST
# We can trade BF.A
# We can trade BFAM
# We can trade BFEB
# We can trade BFIT
# We can trade BFO
# We can trade BCEL
# We can trade BCI
# We can trade BCM
# We can trade BCO
# We can trade BCOR
# We can trade BCOW
# We can trade BCS
# We can trade BCV
# We can trade BCX
# We can trade BDC
# We can trade BDCX
# We can trade BDCZ
# We can trade BDEC
# We can trade BDJ
# We can trade BDRY
# We can trade BDX
# We can trade BEAM
# We can trade BECN
# We can trade BEEM
# We can trade BELFA
# We can trade BEN
# We can trade BEP-A
# We can trade BERY
# We can trade BETZ
# We can trade BF.B
# We can trade BFC
# We can trade BFIN
# We can trade BFK
# We can trade BFOR
# We can trade BFS
# We can trade BFS-E
# We can trade BFT.U
# We can trade BFY
# We can trade BG
# We can trade BGCP
# We can trade BGI
# We can trade BGNE
# We can trade BGRN
# We can trade BGSF
# We can trade BGX
# We can trade BH
# We can trade BFRA
# We can trade BFS-D
# We can trade BFST
# We can trade BFTR
# We can trade BFZ
# We can trade BGB
# We can trade BGFV
# We can trade BGH
# We can trade BGIO
# We can trade BGR
# We can trade BGS
# We can trade BGT
# We can trade BGY
# We can trade BH.A
# We can trade BHB
# We can trade BHE
# We can trade BHFAL
# We can trade BHFAP
# We can trade BHLB
# We can trade BHR-B
# We can trade BHTG
# We can trade BHVN
# We can trade BIBL
# We can trade BIG
# We can trade BIIB
# We can trade BILL
# We can trade BIMI
# We can trade BIO.B
# We can trade BIOL
# We can trade BIP
# We can trade BIPC
# We can trade BIS
# We can trade BITA
# We can trade BIVI
# We can trade BJ
# We can trade BJK
# We can trade BJUL
# We can trade BK
# We can trade BKAG
# We can trade BKD
# We can trade BKEM
# We can trade BKEPP
# We can trade BKH
# We can trade BHAT
# We can trade BHC
# We can trade BHF
# We can trade BHFAO
# We can trade BHK
# We can trade BHR
# We can trade BHR-D
# We can trade BHV
# We can trade BIB
# We can trade BICK
# We can trade BIF
# We can trade BIGC
# We can trade BIL
# We can trade BILS
# We can trade BIO
# We can trade BIOC
# We can trade BIOX
# We can trade BIP-A
# We can trade BIT
# We can trade BIV
# We can trade BIZD
# We can trade BJAN
# We can trade BJRI
# We can trade BJUN
# We can trade BK-C
# We can trade BKCC
# We can trade BKE
# We can trade BKEP
# We can trade BKF
# We can trade BKHY
# We can trade BKIE
# We can trade BKLC
# We can trade BKMC
# We can trade BKNG
# We can trade BKSB
# We can trade BKSE
# We can trade BKTI
# We can trade BKYI
# We can trade BLBD
# We can trade BLCN
# We can trade BLD
# We can trade BLDP
# We can trade BKI
# We can trade BKK
# We can trade BKLN
# We can trade BKN
# We can trade BKR
# We can trade BKSC
# We can trade BKT
# We can trade BKU
# We can trade BL
# We can trade BLCM
# We can trade BLCT
# We can trade BLDG
# We can trade BLDR
# We can trade BLES
# We can trade BLHY
# We can trade BLIN
# We can trade BLKB
# We can trade BLMN
# We can trade BLOK
# We can trade BLRX
# We can trade BLUE
# We can trade BLW
# We can trade BMA
# We can trade BMAY
# We can trade BME
# We can trade BMEZ
# We can trade BML-G
# We can trade BML-J
# We can trade BMLP
# We can trade BMRC
# We can trade BMRG.U
# We can trade BMTC
# We can trade BMY.RT
# We can trade BNDC
# We can trade BNDX
# We can trade BNFT
# We can trade BNKD
# We can trade BNKU
# We can trade BNL
# We can trade BNOV
# We can trade BNS
# We can trade BNTC
# We can trade BNY
# We can trade BLE
# We can trade BLFS
# We can trade BLI
# We can trade BLK
# We can trade BLL
# We can trade BLNK
# We can trade BLPH
# We can trade BLU
# We can trade BLV
# We can trade BLX
# We can trade BMAR
# We can trade BMCH
# We can trade BMED
# We can trade BMI
# We can trade BML-H
# We can trade BML-L
# We can trade BMRA
# We can trade BMRG
# We can trade BMRN
# We can trade BMY
# We can trade BND
# We can trade BNDW
# We can trade BNED
# We can trade BNGO
# We can trade BNKO
# We can trade BNKZ
# We can trade BNO
# We can trade BNR
# We can trade BNSO
# We can trade BNTX
# We can trade BOCH
# We can trade BOE
# We can trade BOIL
# We can trade BOKFL
# We can trade BOMN
# We can trade BOOT
# We can trade BORR
# We can trade BOSS
# We can trade BOTJ
# We can trade BOUT
# We can trade BOX
# We can trade BP
# We can trade BPMC
# We can trade BPOP
# We can trade BOCT
# We can trade BOH
# We can trade BOKF
# We can trade BOOM
# We can trade BOSC
# We can trade BOTZ
# We can trade BOWXU
# We can trade BOXL
# We can trade BPFH
# We can trade BPMP
# We can trade BPOPM
# We can trade BPRN
# We can trade BPTH
# We can trade BPYPN
# We can trade BPYPP
# We can trade BPYUP
# We can trade BQH
# We can trade BRBR
# We can trade BRC
# We can trade BRFS
# We can trade BRG-A
# We can trade BRG-D
# We can trade BRK.A
# We can trade BRKL
# We can trade BRKS
# We can trade BRLIR
# We can trade BRMK
# We can trade BRO
# We can trade BRP
# We can trade BRPAR
# We can trade BRQS
# We can trade BRX
# We can trade BRZU
# We can trade BSAC
# We can trade BSBE
# We can trade BSBR
# We can trade BSCK
# We can trade BSCM
# We can trade BSCO
# We can trade BPOPN
# We can trade BPT
# We can trade BPY
# We can trade BPYPO
# We can trade BPYU
# We can trade BQ
# We can trade BR
# We can trade BRBS
# We can trade BRF
# We can trade BRG
# We can trade BRG-C
# We can trade BRID
# We can trade BRK.B
# We can trade BRKR
# We can trade BRLI
# We can trade BRLIU
# We can trade BRN
# We can trade BROG
# We can trade BRPA
# We can trade BRPAU
# We can trade BRT
# We can trade BRY
# We can trade BSA
# We can trade BSAE
# We can trade BSBK
# We can trade BSCE
# We can trade BSCL
# We can trade BSCN
# We can trade BSCP
# We can trade BSCR
# We can trade BSCT
# We can trade BSD
# We can trade BSE
# We can trade BSET
# We can trade BSIG
# We can trade BSJL
# We can trade BSJN
# We can trade BSJP
# We can trade BSJR
# We can trade BSL
# We can trade BSML
# We can trade BSCQ
# We can trade BSCS
# We can trade BSCU
# We can trade BSDE
# We can trade BSEP
# We can trade BSGM
# We can trade BSJK
# We can trade BSJM
# We can trade BSJO
# We can trade BSJQ
# We can trade BSJS
# We can trade BSM
# We can trade BSMM
# We can trade BSMO
# We can trade BSMQ
# We can trade BSMS
# We can trade BSMX
# We can trade BSRR
# We can trade BSTC
# We can trade BSV
# We can trade BSY
# We can trade BTAI
# We can trade BTAQU
# We can trade BTE
# We can trade BTEK
# We can trade BTI
# We can trade BTO
# We can trade BTU
# We can trade BTZ
# We can trade BUFF
# We can trade BUG
# We can trade BUL
# We can trade BUSE
# We can trade BUYZ
# We can trade BVN
# We can trade BW
# We can trade BWAY
# We can trade BWEN
# We can trade BWG
# We can trade BSMN
# We can trade BSMP
# We can trade BSMR
# We can trade BSMT
# We can trade BSN.U
# We can trade BSQR
# We can trade BST
# We can trade BSTZ
# We can trade BSVN
# We can trade BSX-A
# We can trade BTA
# We can trade BTAL
# We can trade BTBT
# We can trade BTEC
# We can trade BTG
# We can trade BTN
# We can trade BTT
# We can trade BTYS
# We can trade BUD
# We can trade BUFR
# We can trade BUI
# We can trade BURL
# We can trade BUY
# We can trade BV
# We can trade BVH
# We can trade BVXV
# We can trade BWA
# We can trade BWB
# We can trade BWFG
# We can trade BWL.A
# We can trade BWX
# We can trade BWZ
# We can trade BXC
# We can trade BXMT
# We can trade BXP
# We can trade BXRX
# We can trade BXS-A
# We can trade BYD
# We can trade BYLD
# We can trade BYND
# We can trade BZH
# We can trade BZQ
# We can trade BWMX
# We can trade BX
# We can trade BXG
# We can trade BXMX
# We can trade BXP-B
# We can trade BXS
# We can trade BY
# We can trade BYFC
# We can trade BYM
# We can trade BYSI
# We can trade BZM
# We can trade BZUN
# We can trade C-K
# We can trade C-S
# We can trade CAAS
# We can trade CABO
# We can trade CACC
# We can trade CACI
# We can trade CAE
# We can trade CAG
# We can trade CAI
# We can trade CAI-B
# We can trade CAKE
# We can trade CALA
# We can trade CALF
# We can trade CALM
# We can trade CALX
# We can trade CAMT
# We can trade CANE
# We can trade CANG
# We can trade CAPE
# We can trade CAPR
# We can trade CARA
# We can trade CARG
# We can trade CARS
# We can trade CARZ
# We can trade CASH
# We can trade CASS
# We can trade CAT
# We can trade CATC
# We can trade CATM
# We can trade CATY
# We can trade CB
# We can trade CBAT
# We can trade C-J
# We can trade C-N
# We can trade CAAP
# We can trade CABA
# We can trade CAC
# We can trade CACG
# We can trade CADE
# We can trade CAF
# We can trade CAH
# We can trade CAI-A
# We can trade CAJ
# We can trade CAL
# We can trade CALB
# We can trade CALT
# We can trade CAMP
# We can trade CAN
# We can trade CANF
# We can trade CAPAU
# We can trade CAPL
# We can trade CAR
# We can trade CARE
# We can trade CARR
# We can trade CARV
# We can trade CASA
# We can trade CASI
# We can trade CASY
# We can trade CATB
# We can trade CATH
# We can trade CATO
# We can trade CBAN
# We can trade CBAY
# We can trade CBB-B
# We can trade CBFV
# We can trade CBIO
# We can trade CBL-D
# We can trade CBLI
# We can trade CBMG
# We can trade CBOE
# We can trade CBPO
# We can trade CBRL
# We can trade CBB
# We can trade CBD
# We can trade CBH
# We can trade CBL
# We can trade CBL-E
# We can trade CBMB
# We can trade CBNK
# We can trade CBON
# We can trade CBRE
# We can trade CBSH
# We can trade CBU
# We can trade CC
# We can trade CCAC.U
# We can trade CCB
# We can trade CCC
# We can trade CCCL
# We can trade CCEP
# We can trade CCI
# We can trade CCIV
# We can trade CCJ
# We can trade CCL
# We can trade CCM
# We can trade CCMP
# We can trade CCNE
# We can trade CCO
# We can trade CCON
# We can trade CCR
# We can trade CCRN
# We can trade CCS
# We can trade CCX
# We can trade CCXI
# We can trade CD
# We can trade CDC
# We can trade CDEV
# We can trade CDL
# We can trade CDMO
# We can trade CDNA
# We can trade CDOR
# We can trade CDR-B
# We can trade CBT
# We can trade CBTX
# We can trade CBZ
# We can trade CCAC
# We can trade CCAP
# We can trade CCBG
# We can trade CCCC
# We can trade CCD
# We can trade CCF
# We can trade CCIV.U
# We can trade CCK
# We can trade CCLP
# We can trade CCNC
# We can trade CCNEP
# We can trade CCOI
# We can trade CCOR
# We can trade CCRC
# We can trade CCRV
# We can trade CCU
# We can trade CCX.U
# We can trade CCZ
# We can trade CDAY
# We can trade CDE
# We can trade CDK
# We can trade CDLX
# We can trade CDMOP
# We can trade CDNS
# We can trade CDR
# We can trade CDR-C
# We can trade CDTX
# We can trade CDXC
# We can trade CDZI
# We can trade CEA
# We can trade CEE
# We can trade CEFA
# We can trade CEFS
# We can trade CEIX
# We can trade CELC
# We can trade CELH
# We can trade CEM
# We can trade CDW
# We can trade CDXS
# We can trade CE
# We can trade CECE
# We can trade CEF
# We can trade CEFD
# We can trade CEI
# We can trade CEL
# We can trade CELG.RT
# We can trade CELP
# We can trade CEMB
# We can trade CEN
# We can trade CENTA
# We can trade CEO
# We can trade CEQP
# We can trade CERC
# We can trade CERS
# We can trade CETV
# We can trade CETXP
# We can trade CEVA
# We can trade CEY
# We can trade CF
# We can trade CFB
# We can trade CFBK
# We can trade CFFA
# We can trade CFFI
# We can trade CFG
# We can trade CFG-E
# We can trade CFMS
# We can trade CFR
# We can trade CFX
# We can trade CG
# We can trade CGBD
# We can trade CGEN
# We can trade CGIX
# We can trade CGO
# We can trade CGROU
# We can trade CHA
# We can trade CHAQ.U
# We can trade CHB
# We can trade CHCO
# We can trade CHD
# We can trade CEMI
# We can trade CENT
# We can trade CENX
# We can trade CEPU
# We can trade CEQP-
# We can trade CERN
# We can trade CET
# We can trade CETX
# We can trade CEV
# We can trade CEW
# We can trade CEZ
# We can trade CFA
# We can trade CFBI
# We can trade CFCV
# We can trade CFFAU
# We can trade CFFN
# We can trade CFG-D
# We can trade CFIIU
# We can trade CFO
# We can trade CFRX
# We can trade CFXA
# We can trade CGA
# We can trade CGC
# We can trade CGNX
# We can trade CGRO
# We can trade CGW
# We can trade CHAD
# We can trade CHAQ
# We can trade CHAU
# We can trade CHCI
# We can trade CHCT
# We can trade CHDN
# We can trade CHEF
# We can trade CHEP
# We can trade CHGG
# We can trade CHI
# We can trade CHIE
# We can trade CHII
# We can trade CHIL
# We can trade CHIQ
# We can trade CHIS
# We can trade CHIX
# We can trade CHE
# We can trade CHEK
# We can trade CHFS
# We can trade CHGX
# We can trade CHIC
# We can trade CHIH
# We can trade CHIK
# We can trade CHIM
# We can trade CHIR
# We can trade CHIU
# We can trade CHKP
# We can trade CHL
# We can trade CHMG
# We can trade CHMI-A
# We can trade CHN
# We can trade CHNG
# We can trade CHNR
# We can trade CHPMU
# We can trade CHRS
# We can trade CHS
# We can trade CHSCM
# We can trade CHSCO
# We can trade CHT
# We can trade CHU
# We can trade CHW
# We can trade CHX
# We can trade CI
# We can trade CIB
# We can trade CID
# We can trade CIEN
# We can trade CIG
# We can trade CIGI
# We can trade CII
# We can trade CIICU
# We can trade CIL
# We can trade CIM-A
# We can trade CIM-C
# We can trade CINF
# We can trade CIO
# We can trade CIR
# We can trade CIT-B
# We can trade CIX
# We can trade CIZN
# We can trade CHMA
# We can trade CHMI
# We can trade CHMI-B
# We can trade CHNA
# We can trade CHNGU
# We can trade CHPM
# We can trade CHRA
# We can trade CHRW
# We can trade CHSCL
# We can trade CHSCN
# We can trade CHSCP
# We can trade CHTR
# We can trade CHUY
# We can trade CHWY
# We can trade CHY
# We can trade CIA
# We can trade CIBR
# We can trade CIDM
# We can trade CIF
# We can trade CIG.C
# We can trade CIH
# We can trade CIIC
# We can trade CIK
# We can trade CIM
# We can trade CIM-B
# We can trade CIM-D
# We can trade CINR
# We can trade CIO-A
# We can trade CIT
# We can trade CIVB
# We can trade CIZ
# We can trade CJJD
# We can trade CKPT
# We can trade CL
# We can trade CLAR
# We can trade CLBK
# We can trade CLCT
# We can trade CLDR
# We can trade CLDX
# We can trade CLF
# We can trade CLGN
# We can trade CKH
# We can trade CKX
# We can trade CLA.U
# We can trade CLB
# We can trade CLBS
# We can trade CLDB
# We can trade CLDT
# We can trade CLEU
# We can trade CLFD
# We can trade CLGX
# We can trade CLI
# We can trade CLIR
# We can trade CLLS
# We can trade CLMT
# We can trade CLNE
# We can trade CLNY-G
# We can trade CLNY-I
# We can trade CLOU
# We can trade CLPS
# We can trade CLR
# We can trade CLRG
# We can trade CLS
# We can trade CLSK
# We can trade CLTL
# We can trade CLVS
# We can trade CLWT
# We can trade CLXT
# We can trade CMA
# We can trade CMBS
# We can trade CMCL
# We can trade CMCO
# We can trade CMCT
# We can trade CMD
# We can trade CME
# We can trade CMFNL
# We can trade CMI
# We can trade CMLS
# We can trade CMO-E
# We can trade CMPI
# We can trade CMPS
# We can trade CMRE-B
# We can trade CMRE-D
# We can trade CMRX
# We can trade CMS-B
# We can trade CLH
# We can trade CLII.U
# We can trade CLIX
# We can trade CLM
# We can trade CLNC
# We can trade CLNY
# We can trade CLNY-H
# We can trade CLNY-J
# We can trade CLPR
# We can trade CLPT
# We can trade CLRB
# We can trade CLRO
# We can trade CLSD
# We can trade CLSN
# We can trade CLW
# We can trade CLX
# We can trade CM
# We can trade CMBM
# We can trade CMC
# We can trade CMCM
# We can trade CMCSA
# We can trade CMCTP
# We can trade CMDY
# We can trade CMF
# We can trade CMG
# We can trade CMLFU
# We can trade CMO
# We can trade CMP
# We can trade CMPR
# We can trade CMRE
# We can trade CMRE-C
# We can trade CMRE-E
# We can trade CMS
# We can trade CMSA
# We can trade CMSD
# We can trade CMTL
# We can trade CN
# We can trade CNBKA
# We can trade CNC
# We can trade CNCR
# We can trade CNET
# We can trade CNFR
# We can trade CMSC
# We can trade CMT
# We can trade CMU
# We can trade CNA
# We can trade CNBS
# We can trade CNCE
# We can trade CNDT
# We can trade CNF
# We can trade CNFRL
# We can trade CNI
# We can trade CNMD
# We can trade CNNE
# We can trade CNOB
# We can trade CNP-B
# We can trade CNR
# We can trade CNS
# We can trade CNSP
# We can trade CNX
# We can trade CNXT
# We can trade CO
# We can trade CODI
# We can trade CODI-B
# We can trade CODX
# We can trade COF
# We can trade COF-G
# We can trade COF-I
# We can trade COF-K
# We can trade COG
# We can trade COHN
# We can trade COHU
# We can trade COLB
# We can trade COLL
# We can trade COM
# We can trade COMM
# We can trade CONE
# We can trade COO
# We can trade COP
# We can trade COR
# We can trade CORN
# We can trade CORR
# We can trade CORT
# We can trade CNHI
# We can trade CNK
# We can trade CNNB
# We can trade CNO
# We can trade CNP
# We can trade CNQ
# We can trade CNRG
# We can trade CNSL
# We can trade CNST
# We can trade CNTG
# We can trade CNTY
# We can trade CNXN
# We can trade CNYA
# We can trade COCP
# We can trade CODI-A
# We can trade CODI-C
# We can trade COE
# We can trade COF-F
# We can trade COF-H
# We can trade COF-J
# We can trade COFS
# We can trade COGT
# We can trade COHR
# We can trade COKE
# We can trade COLD
# We can trade COLM
# We can trade COMB
# We can trade COMT
# We can trade CONN
# We can trade COOP
# We can trade COPX
# We can trade CORE
# We can trade CORP
# We can trade CORR-A
# We can trade COUP
# We can trade COWN
# We can trade COWNZ
# We can trade CP
# We can trade CPAA
# We can trade CPAC
# We can trade CPB
# We can trade COW
# We can trade COWNL
# We can trade COWZ
# We can trade CPA
# We can trade CPAAU
# We can trade CPAH
# We can trade CPE
# We can trade CPF
# We can trade CPHC
# We can trade CPI
# We can trade CPK
# We can trade CPLP
# We can trade CPRT
# We can trade CPS
# We can trade CPSI
# We can trade CPSR.U
# We can trade CPST
# We can trade CPTA
# We can trade CPTAL
# We can trade CQP
# We can trade CR
# We can trade CRAK
# We can trade CRBP
# We can trade CRD.A
# We can trade CRDF
# We can trade CREG
# We can trade CREX
# We can trade CRH
# We can trade CRHM
# We can trade CRIS
# We can trade CRL
# We can trade CRMD
# We can trade CRNC
# We can trade CRNX
# We can trade CRON
# We can trade CRS
# We can trade CRSAU
# We can trade CRSR
# We can trade CRTD
# We can trade CRTX
# We can trade CRVL
# We can trade CRWD
# We can trade CRY
# We can trade CSA
# We can trade CPER
# We can trade CPG
# We can trade CPHI
# We can trade CPIX
# We can trade CPLG
# We can trade CPRI
# We can trade CPRX
# We can trade CPSH
# We can trade CPSR
# We can trade CPSS
# We can trade CPT
# We can trade CPTAG
# We can trade CPZ
# We can trade CQQQ
# We can trade CRAI
# We can trade CRBN
# We can trade CRD.B
# We can trade CREE
# We can trade CRESY
# We can trade CRF
# We can trade CRHC.U
# We can trade CRI
# We can trade CRK
# We can trade CRM
# We can trade CRMT
# We can trade CRNT
# We can trade CROC
# We can trade CROX
# We can trade CRSA
# We can trade CRSP
# We can trade CRT
# We can trade CRTO
# We can trade CRUS
# We can trade CRVS
# We can trade CRWS
# We can trade CS
# We can trade CSB
# We can trade CSCO
# We can trade CSD
# We can trade CSGP
# We can trade CSII
# We can trade CSL
# We can trade CSM
# We can trade CSOD
# We can trade CSBR
# We can trade CSCW
# We can trade CSF
# We can trade CSGS
# We can trade CSIQ
# We can trade CSLT
# We can trade CSML
# We can trade CSPI
# We can trade CSQ
# We can trade CSSEN
# We can trade CSTE
# We can trade CSTM
# We can trade CSU
# We can trade CSWC
# We can trade CSWI
# We can trade CTA-A
# We can trade CTAA
# We can trade CTB
# We can trade CTBI
# We can trade CTEK
# We can trade CTHR
# We can trade CTIC
# We can trade CTLT
# We can trade CTO
# We can trade CTRA
# We can trade CTRE
# We can trade CTRN
# We can trade CTSH
# We can trade CTT
# We can trade CTXR
# We can trade CTY
# We can trade CUB
# We can trade CUBB
# We can trade CUBI
# We can trade CUBI-D
# We can trade CUBI-F
# We can trade CUK
# We can trade CURE
# We can trade CUT
# We can trade CUZ
# We can trade CVAC
# We can trade CVCO
# We can trade CVET
# We can trade CVGW
# We can trade CSPR
# We can trade CSSE
# We can trade CSSEP
# We can trade CSTL
# We can trade CSTR
# We can trade CSV
# We can trade CSWCL
# We can trade CSX
# We can trade CTA-B
# We can trade CTAS
# We can trade CTBB
# We can trade CTDD
# We can trade CTG
# We can trade CTIB
# We can trade CTK
# We can trade CTMX
# We can trade CTR
# We can trade CTRM
# We can trade CTS
# We can trade CTSO
# We can trade CTVA
# We can trade CTXS
# We can trade CTZ
# We can trade CUBA
# We can trade CUBE
# We can trade CUBI-C
# We can trade CUBI-E
# We can trade CUE
# We can trade CULP
# We can trade CURO
# We can trade CUTR
# We can trade CVA
# We can trade CVBF
# We can trade CVCY
# We can trade CVEO
# We can trade CVGI
# We can trade CVI
# We can trade CVLG
# We can trade CVLY
# We can trade CVNA
# We can trade CVS
# We can trade CVV
# We can trade CVY
# We can trade CVLT
# We can trade CVM
# We can trade CVR
# We can trade CVU
# We can trade CVX
# We can trade CW
# We can trade CWBC
# We can trade CWCO
# We can trade CWEN
# We can trade CWH
# We can trade CWS
# We can trade CWT
# We can trade CXDC
# We can trade CXE
# We can trade CXO
# We can trade CXSE
# We can trade CYAD
# We can trade CYB
# We can trade CYCC
# We can trade CYCN
# We can trade CYH
# We can trade CYRX
# We can trade CZNC
# We can trade CZWI
# We can trade D
# We can trade DADA
# We can trade DAIO
# We can trade DALI
# We can trade DAN
# We can trade DAR
# We can trade DAUD
# We can trade DAVA
# We can trade DB
# We can trade DBAW
# We can trade DBC
# We can trade DBE
# We can trade DBEH
# We can trade DBEU
# We can trade DBGR
# We can trade DBJP
# We can trade DBLV
# We can trade DBO
# We can trade DBP
# We can trade CWB
# We can trade CWBR
# We can trade CWEB
# We can trade CWEN.A
# We can trade CWK
# We can trade CWST
# We can trade CX
# We can trade CXDO
# We can trade CXH
# We can trade CXP
# We can trade CXW
# We can trade CYAN
# We can trade CYBR
# We can trade CYCCP
# We can trade CYD
# We can trade CYRN
# We can trade CYTK
# We can trade CZA
# We can trade CZR
# We can trade CZZ
# We can trade DAC
# We can trade DAKT
# We can trade DALT
# We can trade DAO
# We can trade DARE
# We can trade DAUG
# We can trade DAX
# We can trade DBA
# We can trade DBB
# We can trade DBD
# We can trade DBEF
# We can trade DBEM
# We can trade DBEZ
# We can trade DBI
# We can trade DBL
# We can trade DBMF
# We can trade DBOC
# We can trade DBS
# We can trade DBVT
# We can trade DCF
# We can trade DCI
# We can trade DCOM
# We can trade DCP
# We can trade DBV
# We can trade DBX
# We can trade DCHF
# We can trade DCO
# We can trade DCOMP
# We can trade DCP-B
# We can trade DCPH
# We can trade DCTH
# We can trade DD
# We can trade DDF
# We can trade DDIV
# We can trade DDM
# We can trade DDT
# We can trade DE
# We can trade DECK
# We can trade DEEF
# We can trade DEEP
# We can trade DEFA
# We can trade DEH.U
# We can trade DELL
# We can trade DEN
# We can trade DEO
# We can trade DESP
# We can trade DEUR
# We can trade DEW
# We can trade DFE
# We can trade DFEN
# We can trade DFHT
# We can trade DFIN
# We can trade DFND
# We can trade DFNS
# We can trade DFPH
# We can trade DFS
# We can trade DFVS
# We can trade DGBP
# We can trade DGICB
# We can trade DGL
# We can trade DGLY
# We can trade DGNR.U
# We can trade DGRE
# We can trade DCP-C
# We can trade DCT
# We can trade DCUE
# We can trade DDD
# We can trade DDG
# We can trade DDLS
# We can trade DDOG
# We can trade DDS
# We can trade DDWM
# We can trade DEA
# We can trade DEED
# We can trade DEF
# We can trade DEH
# We can trade DEI
# We can trade DEM
# We can trade DENN
# We can trade DES
# We can trade DEUS
# We can trade DEX
# We can trade DFEB
# We can trade DFFN
# We can trade DFHTU
# We can trade DFJ
# We can trade DFNL
# We can trade DFNS.U
# We can trade DFP
# We can trade DFPHU
# We can trade DFVL
# We can trade DG
# We can trade DGICA
# We can trade DGII
# We can trade DGNR
# We can trade DGP
# We can trade DGRO
# We can trade DGRW
# We can trade DGT
# We can trade DGZ
# We can trade DHCNI
# We can trade DHF
# We can trade DHIL
# We can trade DGRS
# We can trade DGS
# We can trade DGX
# We can trade DHC
# We can trade DHCNL
# We can trade DHI
# We can trade DHR
# We can trade DHR-B
# We can trade DHT
# We can trade DHY
# We can trade DIAL
# We can trade DIG
# We can trade DIN
# We can trade DIOD
# We can trade DISCA
# We can trade DISCK
# We can trade DIT
# We can trade DIVA
# We can trade DIVC
# We can trade DJCB
# We can trade DJCO
# We can trade DJP
# We can trade DJUL
# We can trade DKL
# We can trade DKS
# We can trade DLA
# We can trade DLHC
# We can trade DLNG
# We can trade DLNG-B
# We can trade DLR
# We can trade DLR-G
# We can trade DLR-K
# We can trade DLS
# We can trade DLTR
# We can trade DLY
# We can trade DMAY
# We can trade DMDV
# We can trade DMLP
# We can trade DMRC
# We can trade DMRI
# We can trade DMRM
# We can trade DMS
# We can trade DHR-A
# We can trade DHS
# We can trade DHX
# We can trade DIA
# We can trade DIAX
# We can trade DIM
# We can trade DINT
# We can trade DIS
# We can trade DISCB
# We can trade DISH
# We can trade DIV
# We can trade DIVB
# We can trade DIVO
# We can trade DJCI
# We can trade DJD
# We can trade DJPY
# We can trade DJUN
# We can trade DKNG
# We can trade DL
# We can trade DLB
# We can trade DLN
# We can trade DLNG-A
# We can trade DLPN
# We can trade DLR-C
# We can trade DLR-J
# We can trade DLR-L
# We can trade DLTH
# We can trade DLX
# We can trade DMAC
# We can trade DMB
# We can trade DMF
# We can trade DMO
# We can trade DMRE
# We can trade DMRL
# We can trade DMRS
# We can trade DMTK
# We can trade DMYD
# We can trade DMYT
# We can trade DNB
# We can trade DNK
# We can trade DNL
# We can trade DNOW
# We can trade DMXF
# We can trade DMYD.U
# We can trade DMYT.U
# We can trade DNKN
# We can trade DNLI
# We can trade DNOV
# We can trade DNP
# We can trade DOCU
# We can trade DOGZ
# We can trade DOMO
# We can trade DOO
# We can trade DOOR
# We can trade DOV
# We can trade DOX
# We can trade DPG
# We can trade DPHCU
# We can trade DPZ
# We can trade DRAD
# We can trade DRD
# We can trade DRH
# We can trade DRI
# We can trade DRIP
# We can trade DRN
# We can trade DRQ
# We can trade DRSK
# We can trade DRUA
# We can trade DS
# We can trade DS-C
# We can trade DSE
# We can trade DSGX
# We can trade DSKE
# We can trade DSOC
# We can trade DSS
# We can trade DSTL
# We can trade DSWL
# We can trade DSX-B
# We can trade DTB
# We can trade DTE
# We can trade DTEC
# We can trade DTH
# We can trade DOC
# We can trade DOG
# We can trade DOL
# We can trade DON
# We can trade DOOO
# We can trade DORM
# We can trade DOW
# We can trade DOYU
# We can trade DPHC
# We can trade DPST
# We can trade DQ
# We can trade DRADP
# We can trade DRE
# We can trade DRH-A
# We can trade DRIO
# We can trade DRIV
# We can trade DRNA
# We can trade DRRX
# We can trade DRTT
# We can trade DRW
# We can trade DS-B
# We can trade DS-D
# We can trade DSEP
# We can trade DSI
# We can trade DSL
# We can trade DSM
# We can trade DSPG
# We can trade DSSI
# We can trade DSU
# We can trade DSX
# We can trade DT
# We can trade DTD
# We can trade DTEA
# We can trade DTF
# We can trade DTIL
# We can trade DTLA-
# We can trade DTP
# We can trade DTSS
# We can trade DTY
# We can trade DUC
# We can trade DUK
# We can trade DUKB
# We can trade DTJ
# We can trade DTN
# We can trade DTQ
# We can trade DTW
# We can trade DUAL
# We can trade DUG
# We can trade DUK-A
# We can trade DUKH
# We can trade DUOT
# We can trade DUSA
# We can trade DUST
# We can trade DVAX
# We can trade DVD
# We can trade DVN
# We can trade DVY
# We can trade DVYE
# We can trade DWAT
# We can trade DWCR
# We can trade DWFI
# We can trade DWM
# We can trade DWMF
# We can trade DWSH
# We can trade DWUS
# We can trade DX
# We can trade DX-C
# We can trade DXF
# We can trade DXJ
# We can trade DXLG
# We can trade DXR
# We can trade DY
# We can trade DYFN
# We can trade DYN
# We can trade DYNT
# We can trade DZSI
# We can trade E
# We can trade EAB
# We can trade EAE
# We can trade EAGG
# We can trade EAOA
# We can trade EAOM
# We can trade EARN
# We can trade DUO
# We can trade DURA
# We can trade DUSL
# We can trade DVA
# We can trade DVLU
# We can trade DVOL
# We can trade DVYA
# We can trade DWAS
# We can trade DWAW
# We can trade DWEQ
# We can trade DWMC
# We can trade DWPP
# We can trade DWSN
# We can trade DWX
# We can trade DX-B
# We can trade DXCM
# We can trade DXGE
# We can trade DXJS
# We can trade DXPE
# We can trade DXYN
# We can trade DYAI
# We can trade DYHG
# We can trade DYNF
# We can trade DZK
# We can trade DZZ
# We can trade EA
# We can trade EAD
# We can trade EAF
# We can trade EAI
# We can trade EAOK
# We can trade EAOR
# We can trade EARS
# We can trade EAST
# We can trade EB
# We can trade EBAYL
# We can trade EBIX
# We can trade EBLU
# We can trade EBND
# We can trade EBR
# We can trade EBS
# We can trade EASG
# We can trade EAT
# We can trade EBAY
# We can trade EBF
# We can trade EBIZ
# We can trade EBMT
# We can trade EBON
# We can trade EBR.B
# We can trade EBSB
# We can trade EC
# We can trade ECCB
# We can trade ECCY
# We can trade ECF-A
# We can trade ECHO
# We can trade ECLN
# We can trade ECOL
# We can trade ECON
# We can trade ECOW
# We can trade ECPG
# We can trade ED
# We can trade EDC
# We can trade EDEN
# We can trade EDI
# We can trade EDIV
# We can trade EDNT
# We can trade EDOG
# We can trade EDRY
# We can trade EDTK
# We can trade EDUC
# We can trade EDV
# We can trade EEA
# We can trade EEH
# We can trade EEM
# We can trade EEMD
# We can trade EEMS
# We can trade EEMX
# We can trade EET
# We can trade EEX
# We can trade EFAD
# We can trade EFAV
# We can trade EFC-A
# We can trade EFG
# We can trade EBTC
# We can trade ECC
# We can trade ECCX
# We can trade ECF
# We can trade ECH
# We can trade ECL
# We can trade ECNS
# We can trade ECOM
# We can trade ECOR
# We can trade ECOZ
# We can trade EDAP
# We can trade EDD
# We can trade EDF
# We can trade EDIT
# We can trade EDN
# We can trade EDOC
# We can trade EDOW
# We can trade EDSA
# We can trade EDU
# We can trade EDUT
# We can trade EDZ
# We can trade EEFT
# We can trade EELV
# We can trade EEMA
# We can trade EEMO
# We can trade EEMV
# We can trade EES
# We can trade EEV
# We can trade EFA
# We can trade EFAS
# We can trade EFAX
# We can trade EFC
# We can trade EFF
# We can trade EFIV
# We can trade EFNL
# We can trade EFOI
# We can trade EFSC
# We can trade EFU
# We can trade EFX
# We can trade EGAN
# We can trade EGF
# We can trade EGLE
# We can trade EGOV
# We can trade EFL
# We can trade EFO
# We can trade EFR
# We can trade EFT
# We can trade EFV
# We can trade EFZ
# We can trade EGBN
# We can trade EGHT
# We can trade EGO
# We can trade EGP
# We can trade EGRX
# We can trade EH
# We can trade EHI
# We can trade EHTH
# We can trade EIDO
# We can trade EIG
# We can trade EIGR
# We can trade EINC
# We can trade EIS
# We can trade EJAN
# We can trade EKAR
# We can trade EL
# We can trade ELAN
# We can trade ELC
# We can trade ELF
# We can trade ELLO
# We can trade ELOX
# We can trade ELS
# We can trade ELTK
# We can trade ELVT
# We can trade EMAG
# We can trade EMB
# We can trade EMBH
# We can trade EMCF
# We can trade EMDV
# We can trade EMF
# We can trade EMGF
# We can trade EMIF
# We can trade EMKR
# We can trade EMLC
# We can trade EMNT
# We can trade EMP
# We can trade EGPT
# We can trade EGY
# We can trade EHC
# We can trade EHT
# We can trade EIC
# We can trade EIDX
# We can trade EIGI
# We can trade EIM
# We can trade EIRL
# We can trade EIX
# We can trade EJUL
# We can trade EKSO
# We can trade ELA
# We can trade ELAT
# We can trade ELD
# We can trade ELJ
# We can trade ELMD
# We can trade ELP
# We can trade ELSE
# We can trade ELU
# We can trade ELY
# We can trade EMAN
# We can trade EMBD
# We can trade EMCB
# We can trade EMD
# We can trade EME
# We can trade EMFM
# We can trade EMHY
# We can trade EML
# We can trade EMLP
# We can trade EMMF
# We can trade EMO
# We can trade EMPW.U
# We can trade EMR
# We can trade EMSH
# We can trade EMTY
# We can trade EMXC
# We can trade ENBA
# We can trade ENDP
# We can trade ENG
# We can trade ENIC
# We can trade ENLC
# We can trade EMQQ
# We can trade EMSG
# We can trade EMTL
# We can trade EMX
# We can trade ENB
# We can trade ENBL
# We can trade ENFR
# We can trade ENIA
# We can trade ENJ
# We can trade ENLV
# We can trade ENOB
# We can trade ENPC.U
# We can trade ENR-A
# We can trade ENSG
# We can trade ENTA
# We can trade ENTR
# We can trade ENV
# We can trade ENX
# We can trade ENZL
# We can trade EOD
# We can trade EOI
# We can trade EOS
# We can trade EP-C
# We can trade EPAM
# We can trade EPC
# We can trade EPHE
# We can trade EPIX
# We can trade EPOL
# We can trade EPR
# We can trade EPR-E
# We can trade EPRF
# We can trade EPS
# We can trade EPU
# We can trade EPZM
# We can trade EQAL
# We can trade EQC
# We can trade EQD.U
# We can trade EQH
# We can trade EQIX
# We can trade EQNR
# We can trade EQOS
# We can trade EQRR
# We can trade EQT
# We can trade ENO
# We can trade ENOR
# We can trade ENPH
# We can trade ENS
# We can trade ENSV
# We can trade ENTG
# We can trade ENTX
# We can trade ENVA
# We can trade ENZ
# We can trade EOG
# We can trade EOLS
# We can trade EOT
# We can trade EPAC
# We can trade EPAY
# We can trade EPD
# We can trade EPI
# We can trade EPM
# We can trade EPP
# We can trade EPR-C
# We can trade EPR-G
# We can trade EPRT
# We can trade EPSN
# We can trade EPV
# We can trade EQ
# We can trade EQBK
# We can trade EQC-D
# We can trade EQH-A
# We can trade EQL
# We can trade EQOP
# We can trade EQR
# We can trade EQS
# We can trade EQWL
# We can trade ERC
# We can trade ERESU
# We can trade ERH
# We can trade ERIE
# We can trade ERJ
# We can trade ERM
# We can trade ERUS
# We can trade ERY
# We can trade ES
# We can trade ESBK
# We can trade EQX
# We can trade ERES
# We can trade ERF
# We can trade ERIC
# We can trade ERII
# We can trade ERSX
# We can trade ERX
# We can trade ERYP
# We can trade ESBA
# We can trade ESCA
# We can trade ESE
# We can trade ESEB
# We can trade ESGA
# We can trade ESGD
# We can trade ESGG
# We can trade ESGR
# We can trade ESGRP
# We can trade ESGV
# We can trade ESI
# We can trade ESML
# We can trade ESNG
# We can trade ESP
# We can trade ESPR
# We can trade ESRT
# We can trade ESSA
# We can trade ESSCR
# We can trade ESTA
# We can trade ET
# We can trade ETACU
# We can trade ETG
# We can trade ETHO
# We can trade ETJ
# We can trade ETN
# We can trade ETO
# We can trade ETP-C
# We can trade ETP-E
# We can trade ETRN
# We can trade ETTX
# We can trade ETW
# We can trade ETY
# We can trade EUDV
# We can trade ESCR
# We can trade ESEA
# We can trade ESG
# We can trade ESGC
# We can trade ESGE
# We can trade ESGN
# We can trade ESGRO
# We can trade ESGS
# We can trade ESHY
# We can trade ESLT
# We can trade ESNT
# We can trade ESPO
# We can trade ESQ
# We can trade ESS
# We can trade ESSC
# We can trade ESSCU
# We can trade ESTE
# We can trade ESXB
# We can trade ETAC
# We can trade ETB
# We can trade ETH
# We can trade ETI-
# We can trade ETM
# We can trade ETNB
# We can trade ETON
# We can trade ETP-D
# We can trade ETR
# We can trade ETSY
# We can trade ETV
# We can trade ETX
# We can trade EUDG
# We can trade EUFN
# We can trade EUM
# We can trade EURL
# We can trade EURZ
# We can trade EUSB
# We can trade EV
# We can trade EVBG
# We can trade EVC
# We can trade EVF
# We can trade EVG
# We can trade EVH
# We can trade EUFX
# We can trade EUO
# We can trade EURN
# We can trade EUSA
# We can trade EUSC
# We can trade EVA
# We can trade EVBN
# We can trade EVER
# We can trade EVFM
# We can trade EVGN
# We can trade EVI
# We can trade EVLO
# We can trade EVN
# We can trade EVOL
# We can trade EVR
# We can trade EVRI
# We can trade EVTC
# We can trade EVX
# We can trade EW
# We can trade EWBC
# We can trade EWCO
# We can trade EWG
# We can trade EWH
# We can trade EWJ
# We can trade EWJV
# We can trade EWL
# We can trade EWMC
# We can trade EWO
# We can trade EWQ
# We can trade EWS
# We can trade EWT
# We can trade EWUS
# We can trade EWW
# We can trade EWY
# We can trade EWZS
# We can trade EXC
# We can trade EXEL
# We can trade EXG
# We can trade EXK
# We can trade EXN
# We can trade EXPC
# We can trade EXPD
# We can trade EXPI
# We can trade EXR
# We can trade EXTR
# We can trade EYEG
# We can trade EVK
# We can trade EVM
# We can trade EVOK
# We can trade EVOP
# We can trade EVRG
# We can trade EVT
# We can trade EVV
# We can trade EVY
# We can trade EWA
# ...
# We can trade UITB
# We can trade UJAN
# We can trade UJPY
# We can trade UJUN
# We can trade ULBI
# We can trade ULH
# We can trade ULTA
# We can trade ULVM
# We can trade UMAY
# We can trade UCI
# We can trade UCL
# We can trade UCON
# We can trade UDEC
# We can trade UDOW
# We can trade UE
# We can trade UEIC
# We can trade UEUR
# We can trade UFAB
# We can trade UFEB
# We can trade UFO
# We can trade UFPT
# We can trade UG
# We can trade UGE
# We can trade UGL
# We can trade UGP
# We can trade UHS
# We can trade UI
# We can trade UIS
# We can trade UIVM
# We can trade UJB
# We can trade UJUL
# We can trade UL
# We can trade ULE
# We can trade ULST
# We can trade ULTR
# We can trade UMAR
# We can trade UMBF
# We can trade UMDD
# We can trade UMH-B
# We can trade UMH-D
# We can trade UNAM
# We can trade UNF
# We can trade UNG
# We can trade UNIT
# We can trade UNM
# We can trade UNOV
# We can trade UNTY
# We can trade UOCT
# We can trade UONEK
# We can trade UPRO
# We can trade UPV
# We can trade UMC
# We can trade UMH
# We can trade UMH-C
# We can trade UMPQ
# We can trade UN
# We can trade UNB
# We can trade UNFI
# We can trade UNH
# We can trade UNL
# We can trade UNMA
# We can trade UNP
# We can trade UNVR
# We can trade UONE
# We can trade UPLD
# We can trade UPS
# We can trade UPW
# We can trade URA
# We can trade URE
# We can trade URGN
# We can trade URNM
# We can trade URTH
# We can trade USA
# We can trade USAI
# We can trade USAP
# We can trade USB
# We can trade USB-H
# We can trade USB-O
# We can trade USCI
# We can trade USD
# We can trade USDU
# We can trade USEG
# We can trade USEQ
# We can trade USFR
# We can trade USHY
# We can trade USIG
# We can trade USL
# We can trade USLM
# We can trade USM
# We can trade USMF
# We can trade USNA
# We can trade USOI
# We can trade USSG
# We can trade USV
# We can trade UPWK
# We can trade URBN
# We can trade URG
# We can trade URI
# We can trade UROV
# We can trade URTY
# We can trade USAC
# We can trade USAK
# We can trade USAS
# We can trade USAU
# We can trade USB-A
# We can trade USB-M
# We can trade USB-P
# We can trade USCR
# We can trade USDP
# We can trade USDY
# We can trade USEP
# We can trade USFD
# We can trade USHG
# We can trade USI
# We can trade USIO
# We can trade USLB
# We can trade USMC
# We can trade USMV
# We can trade USO
# We can trade USPH
# We can trade USTB
# We can trade USVM
# We can trade USX
# We can trade UTES
# We can trade UTG
# We can trade UTI
# We can trade UTMD
# We can trade UTSI
# We can trade UTZ
# We can trade UUUU
# We can trade UVSP
# We can trade UVXY
# We can trade UXI
# We can trade UYG
# We can trade UZA
# We can trade UZC
# We can trade USWS
# We can trade USXF
# We can trade UTF
# We can trade UTHR
# We can trade UTL
# We can trade UTRN
# We can trade UTSL
# We can trade UUP
# We can trade UVE
# We can trade UVV
# We can trade UWM
# We can trade UXIN
# We can trade UYM
# We can trade UZB
# We can trade UZD
# We can trade VAC
# We can trade VALT
# We can trade VAMO
# We can trade VAR
# We can trade VB
# We can trade VBFC
# We can trade VBK
# We can trade VBND
# We can trade VBTX
# We can trade VCEB
# We can trade VCF
# We can trade VCIT
# We can trade VCNX
# We can trade VCR
# We can trade VCSH
# We can trade VCV
# We can trade VDC
# We can trade VEA
# We can trade VECO
# We can trade VEEV
# We can trade VEGI
# We can trade VEL
# We can trade VER
# We can trade VERB
# We can trade VERO
# We can trade VERU
# We can trade VERY
# We can trade VETS
# We can trade VFC
# We can trade V
# We can trade VACQU
# We can trade VALQ
# We can trade VALU
# We can trade VAPO
# We can trade VAW
# We can trade VBF
# We can trade VBIV
# We can trade VBLT
# We can trade VBR
# We can trade VC
# We can trade VCEL
# We can trade VCIF
# We can trade VCLT
# We can trade VCRA
# We can trade VCTR
# We can trade VCYT
# We can trade VDE
# We can trade VEC
# We can trade VEDL
# We can trade VEGA
# We can trade VEGN
# We can trade VEON
# We can trade VER-F
# We can trade VERI
# We can trade VERT.U
# We can trade VERX
# We can trade VET
# We can trade VEU
# We can trade VFF
# We can trade VFL
# We can trade VFMF
# We can trade VFMV
# We can trade VFVA
# We can trade VGAC.U
# We can trade VGIT
# We can trade VGLT
# We can trade VGR
# We can trade VGT
# We can trade VHC
# We can trade VHT
# We can trade VIACA
# We can trade VIAV
# We can trade VICR
# We can trade VFH
# We can trade VFLQ
# We can trade VFMO
# We can trade VFQY
# We can trade VG
# We can trade VGI
# We can trade VGK
# We can trade VGM
# We can trade VGSH
# We can trade VGZ
# We can trade VHI
# We can trade VIAC
# We can trade VIAO
# We can trade VICI
# We can trade VIDI
# We can trade VIG
# We can trade VIHAU
# We can trade VIOG
# We can trade VIOT
# We can trade VIPS
# We can trade VIRC
# We can trade VIRT
# We can trade VISL
# We can trade VITL
# We can trade VIVE
# We can trade VIXM
# We can trade VJET
# We can trade VKQ
# We can trade VLDR
# We can trade VLO
# We can trade VLT
# We can trade VLUE
# We can trade AYTU
# We can trade VLYPO
# We can trade VMAC
# We can trade VMBS
# We can trade VMD
# We can trade VMM
# We can trade VMOT
# We can trade VNCE
# We can trade VNE
# We can trade VNLA
# We can trade VNMC
# We can trade VNO-K
# We can trade VIE
# We can trade VIGI
# We can trade VIOO
# We can trade VIOV
# We can trade VIR
# We can trade VIRS
# We can trade VIS
# We can trade VIST
# We can trade VIV
# We can trade VIVO
# We can trade VIXY
# We can trade VKI
# We can trade VKTX
# We can trade VLGEA
# We can trade VLRS
# We can trade VLU
# We can trade VLY
# We can trade VLYPP
# We can trade VMACU
# We can trade VMC
# We can trade VMI
# We can trade VMO
# We can trade VMW
# We can trade VNDA
# We can trade VNET
# We can trade VNM
# We can trade VNO
# We can trade VNO-L
# We can trade VNOM
# We can trade VNRX
# We can trade VO
# We can trade VOD
# We can trade VOLT
# We can trade VONG
# We can trade VOO
# We can trade VOOV
# We can trade VOX
# We can trade VPC
# We can trade VPL
# We can trade VPV
# We can trade VRAI
# We can trade VRCA
# We can trade VNO-M
# We can trade VNQI
# We can trade VNSE
# We can trade VNTR
# We can trade VOC
# We can trade VOE
# We can trade VONE
# We can trade VONV
# We can trade VOOG
# We can trade VOT
# We can trade VOXX
# We can trade VOYA-B
# We can trade VPG
# We can trade VPU
# We can trade VRA
# We can trade VRAY
# We can trade VREX
# We can trade VRM
# We can trade VRNA
# We can trade VRNT
# We can trade VRRM
# We can trade VRS
# We can trade VRSN
# We can trade VRTS
# We can trade VRTV
# We can trade VSAT
# We can trade VSEC
# We can trade VSH
# We can trade VSMV
# We can trade VSS
# We can trade VSTA
# We can trade VSTO
# We can trade VTA
# We can trade VTEB
# We can trade VTHR
# We can trade VTIP
# We can trade VTNR
# We can trade VTSI
# We can trade VTVT
# We can trade VTWO
# We can trade VUG
# We can trade VUZI
# We can trade VVI
# We can trade VVPR
# We can trade VRIG
# We can trade VRME
# We can trade VRNS
# We can trade VRP
# We can trade VRSK
# We can trade VRT
# We can trade VRTU
# We can trade VRTX
# We can trade VSDA
# We can trade VSGX
# We can trade VSL
# We can trade VSPRU
# We can trade VST
# We can trade VSTM
# We can trade VT
# We can trade VTC
# We can trade VTGN
# We can trade VTI
# We can trade VTN
# We can trade VTOL
# We can trade VTRU
# We can trade VTV
# We can trade VTWG
# We can trade VTWV
# We can trade VUSE
# We can trade VV
# We can trade VVNT
# We can trade VVR
# We can trade VWID
# We can trade VWOB
# We can trade VXRT
# We can trade VXX
# We can trade VYGG.U
# We can trade VYM
# We can trade VYNE
# We can trade WAB
# We can trade WAFD
# We can trade WAL
# We can trade WANT
# We can trade WAT
# We can trade WB
# We can trade WBAI
# We can trade WBIF
# We can trade VWO
# We can trade VXF
# We can trade VXUS
# We can trade VXZ
# We can trade VYGR
# We can trade VYMI
# We can trade VZ
# We can trade WABC
# We can trade WAFU
# We can trade WALA
# We can trade WASH
# We can trade WATT
# We can trade WBA
# We can trade WBIE
# We can trade WBIG
# We can trade WBIL
# We can trade WBIT
# We can trade WBK
# We can trade WBS
# We can trade WBT
# We can trade WCC-A
# We can trade WCLD
# We can trade WD
# We can trade WDC
# We can trade WDIV
# We can trade WEA
# We can trade WEBL
# We can trade WEC
# We can trade WELL
# We can trade WERN
# We can trade WETF
# We can trade WEYS
# We can trade WFC
# We can trade WFC-N
# We can trade WFC-P
# We can trade WFC-R
# We can trade WFC-V
# We can trade WFC-X
# We can trade WFC-Z
# We can trade WFHY
# We can trade WGO
# We can trade WHD
# We can trade WBII
# We can trade WBIN
# We can trade WBIY
# We can trade WBND
# We can trade WBS-F
# We can trade WCC
# We can trade WCN
# We can trade WDAY
# We can trade WDFC
# We can trade WDR
# We can trade WEAT
# We can trade WEBS
# We can trade WEI
# We can trade WEN
# We can trade WES
# We can trade WF
# We can trade WFC-L
# We can trade WFC-O
# We can trade WFC-Q
# We can trade WFC-T
# We can trade WFC-W
# We can trade WFC-Y
# We can trade WFH
# We can trade WFIG
# We can trade WH
# We can trade WHF
# We can trade WHG
# We can trade WHLR
# We can trade WHLRP
# We can trade WIA
# We can trade WIL
# We can trade WIMI
# We can trade WINC
# We can trade WINT
# We can trade WIRE
# We can trade WIT
# We can trade WIX
# We can trade WK
# We can trade WKHS
# We can trade WLDN
# We can trade WLFC
# We can trade WHFBZ
# We can trade WHLM
# We can trade WHLRD
# We can trade WHR
# We can trade WIFI
# We can trade WILC
# We can trade WINA
# We can trade WING
# We can trade WINS
# We can trade WIP
# We can trade WISA
# We can trade WIW
# We can trade WIZ
# We can trade WKEY
# We can trade WLDR
# We can trade WLK
# We can trade WLL
# We can trade WM
# We can trade WMC
# We can trade WMGI
# We can trade WMS
# We can trade WNEB
# We can trade WOMN
# We can trade WOR
# We can trade WORX
# We can trade WPC
# We can trade WPF.U
# We can trade WPG-H
# We can trade WPM
# We can trade WPRT
# We can trade WPX
# We can trade WRB-B
# We can trade WRB-D
# We can trade WRB-F
# We can trade WRE
# We can trade WRK
# We can trade WRN
# We can trade WSBC
# We can trade WSBF
# We can trade WSFS
# We can trade WSM
# We can trade WLKP
# We can trade WLTW
# We can trade WMB
# We can trade WMG
# We can trade WMK
# We can trade WMT
# We can trade WNC
# We can trade WNS
# We can trade WOOD
# We can trade WORK
# We can trade WOW
# We can trade WPF
# We can trade WPG
# We can trade WPG-I
# We can trade WPP
# We can trade WPS
# We can trade WRB
# We can trade WRB-C
# We can trade WRB-E
# We can trade WRB-G
# We can trade WRI
# We can trade WRLD
# We can trade WRTC
# We can trade WSBCP
# We can trade WSC
# We can trade WSG
# We can trade WSO
# We can trade WSR
# We can trade WSTG
# We can trade WTER
# We can trade WTFCM
# We can trade WTI
# We can trade WTMF
# We can trade WTREP
# We can trade WTRH
# We can trade WTS
# We can trade WTTR
# We can trade WUGI
# We can trade WVFC
# We can trade WVVIP
# We can trade WWD
# We can trade WWJD
# We can trade WSO.B
# We can trade WST
# We can trade WSTL
# We can trade WTBA
# We can trade WTFC
# We can trade WTFCP
# We can trade WTM
# We can trade WTRE
# We can trade WTRG
# We can trade WTRU
# We can trade WTT
# We can trade WU
# We can trade WVE
# We can trade WVVI
# We can trade WW
# We can trade WWE
# We can trade WWR
# We can trade WY
# We can trade WYNN
# We can trade X
# We can trade XAN
# We can trade XAR
# We can trade XBIO
# We can trade XBUY
# We can trade XCUR
# We can trade XEC
# We can trade XELA
# We can trade XENE
# We can trade XERS
# We can trade XFLT
# We can trade XGN
# We can trade XHE
# We can trade XHS
# We can trade XITK
# We can trade XJR
# We can trade XLC
# We can trade XLF
# We can trade XLI
# We can trade XLNX
# We can trade XLRE
# We can trade XLSR
# We can trade XLV
# We can trade XME
# We can trade XMLV
# We can trade WWW
# We can trade WYND
# We can trade WYY
# We can trade XAIR
# We can trade XAN-C
# We can trade XBI
# We can trade XBIT
# We can trade XCEM
# We can trade XDIV
# We can trade XEL
# We can trade XELB
# We can trade XENT
# We can trade XES
# We can trade XFOR
# We can trade XHB
# We can trade XHR
# We can trade XIN
# We can trade XJH
# We can trade XLB
# We can trade XLE
# We can trade XLG
# We can trade XLK
# We can trade XLP
# We can trade XLRN
# We can trade XLU
# We can trade XLY
# We can trade XMHQ
# We can trade XMMO
# We can trade XMVM
# We can trade XNET
# We can trade XOMA
# We can trade XOP
# We can trade XP
# We can trade XPER
# We can trade XPH
# We can trade XPO
# We can trade XRAY
# We can trade XRT
# We can trade XSD
# We can trade XSHQ
# We can trade XSMO
# We can trade XSPA
# We can trade XSW
# We can trade XTL
# We can trade XMPT
# We can trade XNCR
# We can trade XNTK
# We can trade XOM
# We can trade XONE
# We can trade XOUT
# We can trade XPEL
# We can trade XPEV
# We can trade XPL
# We can trade XPP
# We can trade XRLV
# We can trade XRX
# We can trade XSHD
# We can trade XSLV
# We can trade XSOE
# We can trade XSVM
# We can trade XT
# We can trade XTLB
# We can trade XTNT
# We can trade XVZ
# We can trade XXII
# We can trade XYL
# We can trade XYLG
# We can trade Y
# We can trade YAC.U
# We can trade YANG
# We can trade YCBD
# We can trade YCL
# We can trade YELP
# We can trade YGYIP
# We can trade YIN
# We can trade YJ
# We can trade YLD
# We can trade YMAB
# We can trade YORW
# We can trade YRCW
# We can trade YTRA
# We can trade YVR
# We can trade YY
# We can trade XTN
# We can trade XVV
# We can trade XWEB
# We can trade XYF
# We can trade XYLD
# We can trade YAC
# We can trade YALA
# We can trade YCBD-A
# We can trade YCS
# We can trade YETI
# We can trade YGRN
# We can trade YGYI
# We can trade YI
# We can trade YINN
# We can trade YLCO
# We can trade YLDE
# We can trade YNDX
# We can trade YOLO
# We can trade YPF
# We can trade YRD
# We can trade YTEN
# We can trade YUM
# We can trade YUMC
# We can trade YXI
# We can trade YYY
# We can trade ZAGG
# We can trade ZBRA
# We can trade ZCMD
# We can trade ZDGE
# We can trade ZEN
# We can trade ZG
# We can trade ZGNX
# We can trade ZGYHR
# We can trade ZHOK
# We can trade ZIG
# We can trade ZIONL
# We can trade ZIONO
# We can trade ZIOP
# We can trade ZIXI
# We can trade ZKIN
# We can trade ZM
# We can trade Z
# We can trade ZBH
# We can trade ZCAN
# We can trade ZDEU
# We can trade ZEAL
# We can trade ZEUS
# We can trade ZGBR
# We can trade ZGYH
# We can trade ZGYHU
# We can trade ZI
# We can trade ZION
# We can trade ZIONN
# We can trade ZIONP
# We can trade ZJPN
# We can trade ZLAB
# We can trade ZMLP
# We can trade ZNH
# We can trade ZNTL
# We can trade ZS
# We can trade ZSL
# We can trade ZTR
# We can trade ZUMZ
# We can trade ZVO
# We can trade ZYNE
# We can trade ABB
# We can trade AAA
# We can trade AZYO
# We can trade ZNGA
# We can trade ZOM
# We can trade ZROZ
# We can trade ZSAN
# We can trade ZTO
# We can trade ZTS
# We can trade ZUO
# We can trade ZYME
# We can trade ZYXI
# We can trade AAAU
# We can trade BILI
# We can trade SVA
# We can trade BSMU
# We can trade ALRN
# We can trade AROC
# We can trade BDTX
# We can trade BMO
# We can trade CYBE
# We can trade DXD
# We can trade FAX
# We can trade FRHC
# We can trade GBR
# We can trade HMTV
# We can trade IDE
# We can trade KKR-C
# We can trade MBI
# We can trade MNP
# We can trade NVR
# We can trade PGTI
# We can trade PRLD
# We can trade OTRAU
# We can trade ABG
# We can trade AIC
# We can trade AVNT
# We can trade BDXB
# We can trade CODA
# We can trade DPW
# We can trade ESGU
# We can trade FL
# We can trade GAN
# We can trade GHYB
# We can trade HZNP
# We can trade JW.A
# We can trade LOGC
# We can trade MED
# We can trade NMIH
# We can trade ORAN
# We can trade PNR
# We can trade QID
# We can trade REK
# We can trade SCHD
# We can trade SOVB
# We can trade SPYV
# We can trade SR
# We can trade THC
# We can trade UA
# We can trade UST
# We can trade VVV
# We can trade REGI
# We can trade RING
# We can trade SMIT
# We can trade SPBO
# We can trade SQEW
# We can trade SYKE
# We can trade TRX
# We can trade USRT
# We can trade VNQ
# We can trade W
# We can trade YEXT
# We can trade PAICU
# We can trade STPK
# We can trade EMXF
# We can trade NGA
# We can trade AMD
# We can trade FSLY
# We can trade IBIO
# We can trade MCD
# We can trade DAL
# We can trade DXC
# We can trade HON
# We can trade NOC
# We can trade REGN
# We can trade ROK
# We can trade SNOW
# We can trade SQQQ
# We can trade UAL
# We can trade SGEN
# We can trade IH
# We can trade KRON
# We can trade MPLN
# We can trade IPOE.U
# We can trade PSA-N
# We can trade BFT
# We can trade PXSAP
# We can trade LCYAU
# We can trade AONE
# We can trade BTAQ
# We can trade HYBB
# We can trade FUBO
# We can trade ESTC
# We can trade GDRX
# We can trade KCAC
# We can trade COST
# We can trade DRV
# We can trade FB
# We can trade LUV
# We can trade QQQ
# We can trade RGNX
# We can trade SDOW
# We can trade SPXU
# We can trade TMO
# We can trade VNT
# We can trade SPRB
# We can trade INTZ
# We can trade DCRBU
# We can trade MACUU
# We can trade STTK
# We can trade IPOD.U
# We can trade IPOF.U
# We can trade CLA
# We can trade ADT
# We can trade ATHM
# We can trade A
# We can trade AA
# We can trade CHH
# We can trade C
# We can trade CWI
# We can trade DK
# We can trade FBP
# We can trade ENR
# We can trade EXPR
# We can trade G
# We can trade GGG
# We can trade FE
# We can trade AGR
# We can trade IVZ
# We can trade BOND
# We can trade GE
# We can trade GLD
# We can trade IDEX
# We can trade KODK
# We can trade OGEN
# We can trade SPAQ
# We can trade TSLA
# We can trade UUU
# We can trade VALE
# We can trade AAL
# We can trade AAPL
# We can trade BHP

# %%
def percent_change(asset):
    #Input: asset from api.list_assets()
    #Output: percent change from the last 5 days
    symbol=asset.symbol
    barset = api.get_barset(symbol, 'day', limit=5)
    symbol_bars=barset[symbol]
    if not symbol_bars:
        return 0
    week_open = symbol_bars[0].o
    week_close = symbol_bars[-1].c
    percent_change = (week_close - week_open) / week_open * 100
    return percent_change

# %%
print(percent_change(api.get_asset("AAPL")))
# Out:
# 1.9882373595505622

# %%
import math
def buy():
    assets_to_buy=[]
    for asset in api.list_assets()[:40]:#Only look at first 200
        if asset.tradable:
            if (percent_change(asset)<-10):
                assets_to_buy.append(asset.symbol)
    cash=float(api.get_account().cash)
    money_per_asset=cash/len(assets_to_buy)
    barset=api.get_barset(assets_to_buy,'minute',limit=1)
    for asset in assets_to_buy:
        current_price=barset[asset][0].c
        shares=money_per_asset/current_price
        #shares might not be an integer, =>
        shares=math.floor(shares)
        api.submit_order(
        symbol=asset,
        qty=shares,
        side='buy',
        type='market',
        time_in_force='gtc'
        )

# %%
buy()
print(api.list_positions())
# Out:
# [Position({   'asset_class': 'us_equity',
#     'asset_id': 'd3a02f85-b370-465b-96d7-239885cc8c8d',
#     'avg_entry_price': '2.72',
#     'change_today': '-0.0145454545454545',
#     'cost_basis': '50192.16',
#     'current_price': '2.71',
#     'exchange': 'NYSE',
#     'lastday_price': '2.75',
#     'market_value': '50007.63',
#     'qty': '18453',
#     'side': 'long',
#     'symbol': 'LUB',
#     'unrealized_intraday_pl': '-184.53',
#     'unrealized_intraday_plpc': '-0.0036764705882353',
#     'unrealized_pl': '-184.53',
#     'unrealized_plpc': '-0.0036764705882353'}), Position({   'asset_class': 'us_equity',
#     'asset_id': '93e010f3-8c78-4ba2-b03f-ea686c3f7251',
#     'avg_entry_price': '0.364',
#     'change_today': '-0.02431775195893',
#     'cost_basis': '50521.016',
#     'current_price': '0.3611',
#     'exchange': 'AMEX',
#     'lastday_price': '0.3701',
#     'market_value': '50118.5134',
#     'qty': '138794',
#     'side': 'long',
#     'symbol': 'DNN',
#     'unrealized_intraday_pl': '-402.5026',
#     'unrealized_intraday_plpc': '-0.007967032967033',
#     'unrealized_pl': '-402.5026',
#     'unrealized_plpc': '-0.007967032967033'})]
